# %% [markdown]
# # Tabular Q-learning
#
# This tutorial show how to solve the smart Taxi problem in [OPENAI Gym](https://gym.openai.com/) using tabular Q-learning algorithm.
#
# The smart Taxi job is to pick up the passenger at one location and drop them off in another. Here are a few things that we'd love our Smartcab to take care of:
#
# - Drop off the passenger to the right location.
# - Save passenger's time by taking minimum time possible to drop off
# - Take care of passenger's safety and traffic rules
#
# ![image](./resources/taxiV3.png)

# %%
#!pip install cmake 'gym[atari]' scipy

from collections import defaultdict
import pickle
import random
import click
import gym

# %%
def select_optimal_action(q_table, state, action_space):
    max_q_value_action = None
    max_q_value = 0

    if q_table[state]:
        for action, action_q_value in q_table[state].items():
            if action_q_value >= max_q_value:
                max_q_value = action_q_value
                max_q_value_action = action

    return max_q_value_action if max_q_value_action else action_space.sample()

# %% [markdown]
# ## Train

# %%
# Create the game environment

env = gym.make("Taxi-v3")
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
# The hyperparameters
alpha = 0.1
gamma = 0.6
epsilon = 0.1

NUM_EPISODES = 100000

def update(q_table, env, state):
    if random.uniform(0, 1) < epsilon:
        action = env.action_space.sample()
    else:
        action = select_optimal_action(q_table, state, env.action_space)

    next_state, reward, _, _ = env.step(action)
    old_q_value = q_table[state][action]

    # Check if next_state has q values already
    if not q_table[next_state]:
        q_table[next_state] = {action: 0 for action in range(env.action_space.n)}

    # Maximum q_value for the actions in next state
    next_max = max(q_table[next_state].values())

    # Calculate the new q_value
    new_q_value = (1 - alpha) * old_q_value + alpha * (reward + gamma * next_max)

    # Finally, update the q_value
    q_table[state][action] = new_q_value

    return next_state, reward


def train_agent(q_table, env, num_episodes):
    for i in range(num_episodes):
        state = env.reset()
        if not q_table[state]:
            q_table[state] = {
                action: 0 for action in range(env.action_space.n)}

        epochs = 0
        num_penalties, reward, total_reward = 0, 0, 0
        while reward != 20:
            state, reward = update(q_table, env, state)
            total_reward += reward

            if reward == -10:
                num_penalties += 1

            epochs += 1
        print("\nTraining episode {}".format(i + 1))
        print("Time steps: {}, Penalties: {}, Reward: {}".format(epochs,
                                                                 num_penalties,
                                                                 total_reward))

    print("Training finished.\n")
    return q_table

# %%
q_table = defaultdict(int, {})
q_table = train_agent(q_table, env, NUM_EPISODES)

# save the table for future use
with open("q_table.pickle", "wb") as f:
    pickle.dump(dict(q_table), f)
# Out:
# Training episode 1
# Time steps: 652, Penalties: 221, Reward: -2620
#
# Training episode 2
# Time steps: 1496, Penalties: 496, Reward: -5939
#
# Training episode 3
# Time steps: 862, Penalties: 297, Reward: -3514
#
# Training episode 4
# Time steps: 384, Penalties: 138, Reward: -1605
#
# Training episode 5
# Time steps: 737, Penalties: 250, Reward: -2966
#
# Training episode 6
# Time steps: 344, Penalties: 124, Reward: -1439
#
# Training episode 7
# Time steps: 821, Penalties: 269, Reward: -3221
#
# Training episode 8
# Time steps: 1152, Penalties: 394, Reward: -4677
#
# Training episode 9
# Time steps: 1076, Penalties: 318, Reward: -3917
#
# Training episode 10
# Time steps: 2578, Penalties: 862, Reward: -10315
#
# Training episode 11
# Time steps: 234, Penalties: 60, Reward: -753
#
# Training episode 12
# Time steps: 7080, Penalties: 2308, Reward: -27831
#
# Training episode 13
# Time steps: 766, Penalties: 238, Reward: -2887
#
# Training episode 14
# Time steps: 3688, Penalties: 1190, Reward: -14377
#
# Training episode 15
# Time steps: 3283, Penalties: 1071, Reward: -12901
#
# Training episode 16
# Time steps: 8336, Penalties: 2633, Reward: -32012
#
# Training episode 17
# Time steps: 6332, Penalties: 2069, Reward: -24932
#
# Training episode 18
# Time steps: 1230, Penalties: 402, Reward: -4827
#
# Training episode 19
# Time steps: 1296, Penalties: 422, Reward: -5073
#
# Training episode 20
# Time steps: 2606, Penalties: 805, Reward: -9830
#
# Training episode 21
# Time steps: 885, Penalties: 271, Reward: -3303
#
# Training episode 22
# Time steps: 10183, Penalties: 3356, Reward: -40366
#
# Training episode 23
# Time steps: 3567, Penalties: 1176, Reward: -14130
#
# Training episode 24
# Time steps: 4866, Penalties: 1620, Reward: -19425
#
# Training episode 25
# Time steps: 1736, Penalties: 543, Reward: -6602
#
# Training episode 26
# Time steps: 5369, Penalties: 1796, Reward: -21512
#
# Training episode 27
# Time steps: 533, Penalties: 179, Reward: -2123
#
# Training episode 28
# Time steps: 1251, Penalties: 420, Reward: -5010
#
# Training episode 29
# Time steps: 94, Penalties: 29, Reward: -334
#
# Training episode 30
# Time steps: 3813, Penalties: 1262, Reward: -15150
#
# Training episode 31
# Time steps: 297, Penalties: 89, Reward: -1077
#
# Training episode 32
# Time steps: 2113, Penalties: 705, Reward: -8437
#
# Training episode 33
# Time steps: 2383, Penalties: 720, Reward: -8842
#
# Training episode 34
# Time steps: 1319, Penalties: 432, Reward: -5186
#
# Training episode 35
# Time steps: 530, Penalties: 178, Reward: -2111
#
# Training episode 36
# Time steps: 490, Penalties: 175, Reward: -2044
#
# Training episode 37
# Time steps: 3828, Penalties: 1230, Reward: -14877
#
# Training episode 38
# Time steps: 773, Penalties: 232, Reward: -2840
#
# Training episode 39
# Time steps: 602, Penalties: 185, Reward: -2246
#
# Training episode 40
# Time steps: 4165, Penalties: 1357, Reward: -16357
#
# Training episode 41
# Time steps: 287, Penalties: 90, Reward: -1076
#
# Training episode 42
# Time steps: 6745, Penalties: 2189, Reward: -26425
#
# Training episode 43
# Time steps: 2549, Penalties: 821, Reward: -9917
#
# Training episode 44
# Time steps: 613, Penalties: 190, Reward: -2302
#
# Training episode 45
# Time steps: 900, Penalties: 295, Reward: -3534
#
# Training episode 46
# Time steps: 676, Penalties: 221, Reward: -2644
#
# Training episode 47
# Time steps: 1869, Penalties: 596, Reward: -7212
#
# Training episode 48
# Time steps: 450, Penalties: 152, Reward: -1797
#
# Training episode 49
# Time steps: 715, Penalties: 207, Reward: -2557
#
# Training episode 50
# Time steps: 717, Penalties: 242, Reward: -2874
#
# Training episode 51
# Time steps: 2955, Penalties: 973, Reward: -11691
#
# Training episode 52
# Time steps: 4286, Penalties: 1400, Reward: -16865
#
# Training episode 53
# Time steps: 624, Penalties: 188, Reward: -2295
#
# Training episode 54
# Time steps: 400, Penalties: 129, Reward: -1540
#
# Training episode 55
# Time steps: 8405, Penalties: 2703, Reward: -32711
#
# Training episode 56
# Time steps: 1445, Penalties: 465, Reward: -5609
#
# Training episode 57
# Time steps: 324, Penalties: 98, Reward: -1185
#
# Training episode 58
# Time steps: 865, Penalties: 277, Reward: -3337
#
# Training episode 59
# Time steps: 1530, Penalties: 483, Reward: -5856
#
# Training episode 60
# Time steps: 819, Penalties: 246, Reward: -3012
#
# Training episode 61
# Time steps: 1378, Penalties: 458, Reward: -5479
#
# Training episode 62
# Time steps: 241, Penalties: 68, Reward: -832
#
# Training episode 63
# Time steps: 730, Penalties: 240, Reward: -2869
#
# Training episode 64
# Time steps: 531, Penalties: 148, Reward: -1842
#
# Training episode 65
# Time steps: 668, Penalties: 230, Reward: -2717
#
# Training episode 66
# Time steps: 600, Penalties: 200, Reward: -2379
#
# Training episode 67
# Time steps: 525, Penalties: 180, Reward: -2124
#
# Training episode 68
# Time steps: 1808, Penalties: 587, Reward: -7070
#
# Training episode 69
# Time steps: 297, Penalties: 92, Reward: -1104
#
# Training episode 70
# Time steps: 655, Penalties: 185, Reward: -2299
#
# Training episode 71
# Time steps: 125, Penalties: 36, Reward: -428
#
# Training episode 72
# Time steps: 2095, Penalties: 671, Reward: -8113
#
# Training episode 73
# Time steps: 579, Penalties: 185, Reward: -2223
#
# Training episode 74
# Time steps: 2804, Penalties: 912, Reward: -10991
#
# Training episode 75
# Time steps: 342, Penalties: 116, Reward: -1365
#
# Training episode 76
# Time steps: 1584, Penalties: 519, Reward: -6234
#
# Training episode 77
# Time steps: 879, Penalties: 285, Reward: -3423
#
# Training episode 78
# Time steps: 1842, Penalties: 574, Reward: -6987
#
# Training episode 79
# Time steps: 3174, Penalties: 1008, Reward: -12225
#
# Training episode 80
# Time steps: 1394, Penalties: 465, Reward: -5558
#
# Training episode 81
# Time steps: 5698, Penalties: 1861, Reward: -22426
#
# Training episode 82
# Time steps: 1093, Penalties: 372, Reward: -4420
#
# Training episode 83
# Time steps: 182, Penalties: 61, Reward: -710
#
# Training episode 84
# Time steps: 787, Penalties: 257, Reward: -3079
#
# Training episode 85
# Time steps: 1163, Penalties: 368, Reward: -4454
#
# Training episode 86
# Time steps: 377, Penalties: 115, Reward: -1391
#
# Training episode 87
# Time steps: 1281, Penalties: 396, Reward: -4824
#
# Training episode 88
# Time steps: 2942, Penalties: 990, Reward: -11831
#
# Training episode 89
# Time steps: 13784, Penalties: 4513, Reward: -54380
#
# Training episode 90
# Time steps: 1557, Penalties: 479, Reward: -5847
#
# Training episode 91
# Time steps: 955, Penalties: 291, Reward: -3553
#
# Training episode 92
# Time steps: 1768, Penalties: 590, Reward: -7057
#
# Training episode 93
# Time steps: 515, Penalties: 157, Reward: -1907
#
# Training episode 94
# Time steps: 73, Penalties: 27, Reward: -295
#
# Training episode 95
# Time steps: 1196, Penalties: 420, Reward: -4955
#
# Training episode 96
# Time steps: 497, Penalties: 152, Reward: -1844
#
# Training episode 97
# Time steps: 156, Penalties: 43, Reward: -522
#
# Training episode 98
# Time steps: 455, Penalties: 135, Reward: -1649
#
# Training episode 99
# Time steps: 1701, Penalties: 568, Reward: -6792
#
# Training episode 100
# Time steps: 562, Penalties: 200, Reward: -2341
#
# Training episode 101
# Time steps: 530, Penalties: 172, Reward: -2057
#
# Training episode 102
# Time steps: 493, Penalties: 163, Reward: -1939
#
# Training episode 103
# Time steps: 877, Penalties: 288, Reward: -3448
#
# Training episode 104
# Time steps: 373, Penalties: 118, Reward: -1414
#
# Training episode 105
# Time steps: 2502, Penalties: 852, Reward: -10149
#
# Training episode 106
# Time steps: 301, Penalties: 93, Reward: -1117
#
# Training episode 107
# Time steps: 680, Penalties: 217, Reward: -2612
#
# Training episode 108
# Time steps: 120, Penalties: 48, Reward: -531
#
# Training episode 109
# Time steps: 762, Penalties: 264, Reward: -3117
#
# Training episode 110
# Time steps: 814, Penalties: 249, Reward: -3034
#
# Training episode 111
# Time steps: 651, Penalties: 202, Reward: -2448
#
# Training episode 112
# Time steps: 4049, Penalties: 1334, Reward: -16034
#
# Training episode 113
# Time steps: 405, Penalties: 130, Reward: -1554
#
# Training episode 114
# Time steps: 227, Penalties: 68, Reward: -818
#
# Training episode 115
# Time steps: 368, Penalties: 111, Reward: -1346
#
# Training episode 116
# Time steps: 233, Penalties: 72, Reward: -860
#
# Training episode 117
# Time steps: 1599, Penalties: 495, Reward: -6033
#
# Training episode 118
# Time steps: 465, Penalties: 144, Reward: -1740
#
# Training episode 119
# Time steps: 263, Penalties: 86, Reward: -1016
#
# Training episode 120
# Time steps: 1439, Penalties: 488, Reward: -5810
#
# Training episode 121
# Time steps: 3672, Penalties: 1185, Reward: -14316
#
# Training episode 122
# Time steps: 3389, Penalties: 1093, Reward: -13205
#
# Training episode 123
# Time steps: 119, Penalties: 42, Reward: -476
#
# Training episode 124
# Time steps: 958, Penalties: 248, Reward: -3169
#
# Training episode 125
# Time steps: 4033, Penalties: 1320, Reward: -15892
#
# Training episode 126
# Time steps: 4031, Penalties: 1363, Reward: -16277
#
# Training episode 127
# Time steps: 108, Penalties: 43, Reward: -474
#
# Training episode 128
# Time steps: 4070, Penalties: 1278, Reward: -15551
#
# Training episode 129
# Time steps: 462, Penalties: 162, Reward: -1899
#
# Training episode 130
# Time steps: 1055, Penalties: 352, Reward: -4202
#
# Training episode 131
# Time steps: 805, Penalties: 268, Reward: -3196
#
# Training episode 132
# Time steps: 833, Penalties: 262, Reward: -3170
#
# Training episode 133
# Time steps: 4757, Penalties: 1490, Reward: -18146
#
# Training episode 134
# Time steps: 112, Penalties: 33, Reward: -388
#
# Training episode 135
# Time steps: 216, Penalties: 70, Reward: -825
#
# Training episode 136
# Time steps: 1072, Penalties: 343, Reward: -4138
#
# Training episode 137
# Time steps: 739, Penalties: 219, Reward: -2689
#
# Training episode 138
# Time steps: 294, Penalties: 84, Reward: -1029
# Training episode 139
# Time steps: 930, Penalties: 279, Reward: -3420
#
# Training episode 140
# Time steps: 55, Penalties: 10, Reward: -124
#
# Training episode 141
# Time steps: 574, Penalties: 177, Reward: -2146
#
# Training episode 142
# Time steps: 1082, Penalties: 342, Reward: -4139
#
# Training episode 143
# Time steps: 1812, Penalties: 578, Reward: -6993
#
# Training episode 144
# Time steps: 593, Penalties: 178, Reward: -2174
#
# Training episode 145
# Time steps: 658, Penalties: 207, Reward: -2500
#
# Training episode 146
# Time steps: 1110, Penalties: 368, Reward: -4401
#
# Training episode 147
# Time steps: 226, Penalties: 68, Reward: -817
#
# Training episode 148
# Time steps: 149, Penalties: 47, Reward: -551
#
# Training episode 149
# Time steps: 3559, Penalties: 1207, Reward: -14401
#
# Training episode 150
# Time steps: 146, Penalties: 49, Reward: -566
#
# Training episode 151
# Time steps: 1290, Penalties: 423, Reward: -5076
#
# Training episode 152
# Time steps: 1251, Penalties: 407, Reward: -4893
#
# Training episode 153
# Time steps: 4665, Penalties: 1539, Reward: -18495
#
# Training episode 154
# Time steps: 325, Penalties: 102, Reward: -1222
#
# Training episode 155
# Time steps: 235, Penalties: 75, Reward: -889
#
# Training episode 156
# Time steps: 930, Penalties: 287, Reward: -3492
#
# Training episode 157
# Time steps: 332, Penalties: 103, Reward: -1238
#
# Training episode 158
# Time steps: 1416, Penalties: 492, Reward: -5823
#
# Training episode 159
# Time steps: 637, Penalties: 206, Reward: -2470
#
# Training episode 160
# Time steps: 767, Penalties: 210, Reward: -2636
#
# Training episode 161
# Time steps: 2106, Penalties: 664, Reward: -8061
#
# Training episode 162
# Time steps: 337, Penalties: 111, Reward: -1315
#
# Training episode 163
# Time steps: 792, Penalties: 265, Reward: -3156
#
# Training episode 164
# Time steps: 2392, Penalties: 779, Reward: -9382
#
# Training episode 165
# Time steps: 5427, Penalties: 1743, Reward: -21093
#
# Training episode 166
# Time steps: 2271, Penalties: 746, Reward: -8964
#
# Training episode 167
# Time steps: 154, Penalties: 48, Reward: -565
#
# Training episode 168
# Time steps: 219, Penalties: 78, Reward: -900
#
# Training episode 169
# Time steps: 2155, Penalties: 725, Reward: -8659
#
# Training episode 170
# Time steps: 318, Penalties: 97, Reward: -1170
#
# Training episode 171
# Time steps: 44, Penalties: 11, Reward: -122
#
# Training episode 172
# Time steps: 265, Penalties: 76, Reward: -928
#
# Training episode 173
# Time steps: 677, Penalties: 203, Reward: -2483
#
# Training episode 174
# Time steps: 217, Penalties: 68, Reward: -808
#
# Training episode 175
# Time steps: 350, Penalties: 106, Reward: -1283
#
# Training episode 176
# Time steps: 1822, Penalties: 578, Reward: -7003
#
# Training episode 177
# Time steps: 1732, Penalties: 546, Reward: -6625
#
# Training episode 178
# Time steps: 609, Penalties: 208, Reward: -2460
#
# Training episode 179
# Time steps: 629, Penalties: 225, Reward: -2633
#
# Training episode 180
# Time steps: 3331, Penalties: 1022, Reward: -12508
#
# Training episode 181
# Time steps: 1102, Penalties: 367, Reward: -4384
#
# Training episode 182
# Time steps: 2315, Penalties: 726, Reward: -8828
#
# Training episode 183
# Time steps: 686, Penalties: 207, Reward: -2528
#
# Training episode 184
# Time steps: 1777, Penalties: 590, Reward: -7066
#
# Training episode 185
# Time steps: 1485, Penalties: 477, Reward: -5757
#
# Training episode 186
# Time steps: 696, Penalties: 208, Reward: -2547
#
# Training episode 187
# Time steps: 1956, Penalties: 624, Reward: -7551
#
# Training episode 188
# Time steps: 338, Penalties: 103, Reward: -1244
#
# Training episode 189
# Time steps: 476, Penalties: 160, Reward: -1895
#
# Training episode 190
# Time steps: 566, Penalties: 199, Reward: -2336
#
# Training episode 191
# Time steps: 520, Penalties: 155, Reward: -1894
#
# Training episode 192
# Time steps: 1350, Penalties: 447, Reward: -5352
#
# Training episode 193
# Time steps: 531, Penalties: 156, Reward: -1914
#
# Training episode 194
# Time steps: 235, Penalties: 85, Reward: -979
#
# Training episode 195
# Time steps: 3046, Penalties: 982, Reward: -11863
#
# Training episode 196
# Time steps: 1536, Penalties: 506, Reward: -6069
#
# Training episode 197
# Time steps: 106, Penalties: 37, Reward: -418
#
# Training episode 198
# Time steps: 460, Penalties: 154, Reward: -1825
#
# Training episode 199
# Time steps: 1690, Penalties: 512, Reward: -6277
#
# Training episode 200
# Time steps: 337, Penalties: 98, Reward: -1198
#
# Training episode 201
# Time steps: 445, Penalties: 150, Reward: -1774
#
# Training episode 202
# Time steps: 131, Penalties: 50, Reward: -560
#
# Training episode 203
# Time steps: 545, Penalties: 172, Reward: -2072
#
# Training episode 204
# Time steps: 173, Penalties: 49, Reward: -593
#
# Training episode 205
# Time steps: 422, Penalties: 152, Reward: -1769
#
# Training episode 206
# Time steps: 238, Penalties: 81, Reward: -946
#
# Training episode 207
# Time steps: 207, Penalties: 64, Reward: -762
#
# Training episode 208
# Time steps: 271, Penalties: 86, Reward: -1024
#
# Training episode 209
# Time steps: 845, Penalties: 264, Reward: -3200
#
# Training episode 210
# Time steps: 1542, Penalties: 526, Reward: -6255
#
# Training episode 211
# Time steps: 133, Penalties: 38, Reward: -454
#
# Training episode 212
# Time steps: 22, Penalties: 2, Reward: -19
#
# Training episode 213
# Time steps: 360, Penalties: 108, Reward: -1311
#
# Training episode 214
# Time steps: 1615, Penalties: 534, Reward: -6400
#
# Training episode 215
# Time steps: 915, Penalties: 323, Reward: -3801
#
# Training episode 216
# Time steps: 327, Penalties: 116, Reward: -1350
#
# Training episode 217
# Time steps: 235, Penalties: 81, Reward: -943
#
# Training episode 218
# Time steps: 825, Penalties: 268, Reward: -3216
#
# Training episode 219
# Time steps: 245, Penalties: 82, Reward: -962
#
# Training episode 220
# Time steps: 34, Penalties: 8, Reward: -85
#
# Training episode 221
# Time steps: 535, Penalties: 170, Reward: -2044
#
# Training episode 222
# Time steps: 796, Penalties: 240, Reward: -2935
#
# Training episode 223
# Time steps: 994, Penalties: 278, Reward: -3475
#
# Training episode 224
# Time steps: 1460, Penalties: 508, Reward: -6011
#
# Training episode 225
# Time steps: 679, Penalties: 236, Reward: -2782
#
# Training episode 226
# Time steps: 662, Penalties: 206, Reward: -2495
#
# Training episode 227
# Time steps: 285, Penalties: 90, Reward: -1074
#
# Training episode 228
# Time steps: 579, Penalties: 181, Reward: -2187
#
# Training episode 229
# Time steps: 503, Penalties: 156, Reward: -1886
#
# Training episode 230
# Time steps: 344, Penalties: 110, Reward: -1313
#
# Training episode 231
# Time steps: 1678, Penalties: 468, Reward: -5869
#
# Training episode 232
# Time steps: 510, Penalties: 164, Reward: -1965
#
# Training episode 233
# Time steps: 208, Penalties: 71, Reward: -826
#
# Training episode 234
# Time steps: 157, Penalties: 51, Reward: -595
#
# Training episode 235
# Time steps: 92, Penalties: 26, Reward: -305
#
# Training episode 236
# Time steps: 103, Penalties: 24, Reward: -298
#
# Training episode 237
# Time steps: 898, Penalties: 318, Reward: -3739
#
# Training episode 238
# Time steps: 94, Penalties: 27, Reward: -316
#
# Training episode 239
# Time steps: 1242, Penalties: 377, Reward: -4614
#
# Training episode 240
# Time steps: 699, Penalties: 215, Reward: -2613
#
# Training episode 241
# Time steps: 152, Penalties: 44, Reward: -527
#
# Training episode 242
# Time steps: 1158, Penalties: 364, Reward: -4413
#
# Training episode 243
# Time steps: 720, Penalties: 223, Reward: -2706
#
# Training episode 244
# Time steps: 430, Penalties: 145, Reward: -1714
#
# Training episode 245
# Time steps: 153, Penalties: 49, Reward: -573
#
# Training episode 246
# Time steps: 1014, Penalties: 304, Reward: -3729
#
# Training episode 247
# Time steps: 173, Penalties: 56, Reward: -656
#
# Training episode 248
# Time steps: 1114, Penalties: 359, Reward: -4324
#
# Training episode 249
# Time steps: 1655, Penalties: 526, Reward: -6368
#
# Training episode 250
# Time steps: 131, Penalties: 31, Reward: -389
#
# Training episode 251
# Time steps: 1605, Penalties: 513, Reward: -6201
#
# Training episode 252
# Time steps: 1021, Penalties: 342, Reward: -4078
#
# Training episode 253
# Time steps: 1428, Penalties: 462, Reward: -5565
#
# Training episode 254
# Time steps: 5000, Penalties: 1609, Reward: -19460
#
# Training episode 255
# Time steps: 1179, Penalties: 385, Reward: -4623
#
# Training episode 256
# Time steps: 334, Penalties: 102, Reward: -1231
#
# Training episode 257
# Time steps: 311, Penalties: 106, Reward: -1244
#
# Training episode 258
# Time steps: 1593, Penalties: 528, Reward: -6324
#
# Training episode 259
# Time steps: 1554, Penalties: 490, Reward: -5943
#
# Training episode 260
# Time steps: 247, Penalties: 65, Reward: -811
#
# Training episode 261
# Time steps: 1103, Penalties: 360, Reward: -4322
#
# Training episode 262
# Time steps: 490, Penalties: 171, Reward: -2008
#
# Training episode 263
# Time steps: 3528, Penalties: 1171, Reward: -14046
# Training episode 264
# Time steps: 2864, Penalties: 981, Reward: -11672
#
# Training episode 265
# Time steps: 924, Penalties: 303, Reward: -3630
#
# Training episode 266
# Time steps: 94, Penalties: 23, Reward: -280
#
# Training episode 267
# Time steps: 1302, Penalties: 445, Reward: -5286
#
# Training episode 268
# Time steps: 1672, Penalties: 533, Reward: -6448
#
# Training episode 269
# Time steps: 940, Penalties: 315, Reward: -3754
#
# Training episode 270
# Time steps: 1015, Penalties: 341, Reward: -4063
#
# Training episode 271
# Time steps: 1083, Penalties: 362, Reward: -4320
#
# Training episode 272
# Time steps: 268, Penalties: 93, Reward: -1084
#
# Training episode 273
# Time steps: 2002, Penalties: 637, Reward: -7714
#
# Training episode 274
# Time steps: 1756, Penalties: 610, Reward: -7225
#
# Training episode 275
# Time steps: 206, Penalties: 55, Reward: -680
#
# Training episode 276
# Time steps: 693, Penalties: 210, Reward: -2562
#
# Training episode 277
# Time steps: 439, Penalties: 147, Reward: -1741
#
# Training episode 278
# Time steps: 1441, Penalties: 471, Reward: -5659
#
# Training episode 279
# Time steps: 1094, Penalties: 358, Reward: -4295
#
# Training episode 280
# Time steps: 359, Penalties: 104, Reward: -1274
#
# Training episode 281
# Time steps: 1859, Penalties: 613, Reward: -7355
#
# Training episode 282
# Time steps: 1998, Penalties: 673, Reward: -8034
#
# Training episode 283
# Time steps: 58, Penalties: 16, Reward: -181
#
# Training episode 284
# Time steps: 348, Penalties: 142, Reward: -1605
#
# Training episode 285
# Time steps: 41, Penalties: 9, Reward: -101
#
# Training episode 286
# Time steps: 376, Penalties: 116, Reward: -1399
#
# Training episode 287
# Time steps: 245, Penalties: 70, Reward: -854
#
# Training episode 288
# Time steps: 415, Penalties: 122, Reward: -1492
#
# Training episode 289
# Time steps: 615, Penalties: 201, Reward: -2403
#
# Training episode 290
# Time steps: 3273, Penalties: 1088, Reward: -13044
#
# Training episode 291
# Time steps: 1469, Penalties: 476, Reward: -5732
#
# Training episode 292
# Time steps: 873, Penalties: 271, Reward: -3291
#
# Training episode 293
# Time steps: 1275, Penalties: 427, Reward: -5097
#
# Training episode 294
# Time steps: 1208, Penalties: 412, Reward: -4895
#
# Training episode 295
# Time steps: 67, Penalties: 15, Reward: -181
#
# Training episode 296
# Time steps: 204, Penalties: 63, Reward: -750
#
# Training episode 297
# Time steps: 248, Penalties: 83, Reward: -974
#
# Training episode 298
# Time steps: 237, Penalties: 81, Reward: -945
#
# Training episode 299
# Time steps: 1005, Penalties: 315, Reward: -3819
#
# Training episode 300
# Time steps: 5665, Penalties: 1813, Reward: -21961
#
# Training episode 301
# Time steps: 147, Penalties: 39, Reward: -477
#
# Training episode 302
# Time steps: 1236, Penalties: 400, Reward: -4815
#
# Training episode 303
# Time steps: 392, Penalties: 120, Reward: -1451
#
# Training episode 304
# Time steps: 137, Penalties: 43, Reward: -503
#
# Training episode 305
# Time steps: 670, Penalties: 188, Reward: -2341
#
# Training episode 306
# Time steps: 333, Penalties: 111, Reward: -1311
#
# Training episode 307
# Time steps: 1263, Penalties: 387, Reward: -4725
#
# Training episode 308
# Time steps: 439, Penalties: 127, Reward: -1561
#
# Training episode 309
# Time steps: 228, Penalties: 63, Reward: -774
#
# Training episode 310
# Time steps: 1084, Penalties: 339, Reward: -4114
#
# Training episode 311
# Time steps: 2268, Penalties: 767, Reward: -9150
#
# Training episode 312
# Time steps: 184, Penalties: 58, Reward: -685
#
# Training episode 313
# Time steps: 422, Penalties: 127, Reward: -1544
#
# Training episode 314
# Time steps: 1652, Penalties: 543, Reward: -6518
#
# Training episode 315
# Time steps: 333, Penalties: 80, Reward: -1032
#
# Training episode 316
# Time steps: 805, Penalties: 229, Reward: -2845
#
# Training episode 317
# Time steps: 437, Penalties: 131, Reward: -1595
#
# Training episode 318
# Time steps: 3105, Penalties: 1033, Reward: -12381
#
# Training episode 319
# Time steps: 26, Penalties: 7, Reward: -68
#
# Training episode 320
# Time steps: 482, Penalties: 155, Reward: -1856
#
# Training episode 321
# Time steps: 865, Penalties: 304, Reward: -3580
#
# Training episode 322
# Time steps: 1425, Penalties: 443, Reward: -5391
#
# Training episode 323
# Time steps: 535, Penalties: 174, Reward: -2080
#
# Training episode 324
# Time steps: 1219, Penalties: 384, Reward: -4654
#
# Training episode 325
# Time steps: 2274, Penalties: 743, Reward: -8940
#
# Training episode 326
# Time steps: 1782, Penalties: 562, Reward: -6819
#
# Training episode 327
# Time steps: 284, Penalties: 96, Reward: -1127
#
# Training episode 328
# Time steps: 145, Penalties: 41, Reward: -493
#
# Training episode 329
# Time steps: 294, Penalties: 104, Reward: -1209
#
# Training episode 330
# Time steps: 461, Penalties: 139, Reward: -1691
#
# Training episode 331
# Time steps: 539, Penalties: 172, Reward: -2066
#
# Training episode 332
# Time steps: 726, Penalties: 222, Reward: -2703
#
# Training episode 333
# Time steps: 1057, Penalties: 323, Reward: -3943
#
# Training episode 334
# Time steps: 4020, Penalties: 1394, Reward: -16545
#
# Training episode 335
# Time steps: 772, Penalties: 243, Reward: -2938
#
# Training episode 336
# Time steps: 1422, Penalties: 450, Reward: -5451
#
# Training episode 337
# Time steps: 1408, Penalties: 450, Reward: -5437
#
# Training episode 338
# Time steps: 3994, Penalties: 1297, Reward: -15646
#
# Training episode 339
# Time steps: 215, Penalties: 67, Reward: -797
#
# Training episode 340
# Time steps: 55, Penalties: 16, Reward: -178
#
# Training episode 341
# Time steps: 276, Penalties: 95, Reward: -1110
#
# Training episode 342
# Time steps: 418, Penalties: 137, Reward: -1630
#
# Training episode 343
# Time steps: 1875, Penalties: 629, Reward: -7515
#
# Training episode 344
# Time steps: 522, Penalties: 152, Reward: -1869
#
# Training episode 345
# Time steps: 579, Penalties: 191, Reward: -2277
#
# Training episode 346
# Time steps: 2265, Penalties: 734, Reward: -8850
#
# Training episode 347
# Time steps: 377, Penalties: 116, Reward: -1400
#
# Training episode 348
# Time steps: 563, Penalties: 176, Reward: -2126
#
# Training episode 349
# Time steps: 1814, Penalties: 622, Reward: -7391
#
# Training episode 350
# Time steps: 2075, Penalties: 675, Reward: -8129
#
# Training episode 351
# Time steps: 207, Penalties: 81, Reward: -915
#
# Training episode 352
# Time steps: 1622, Penalties: 531, Reward: -6380
#
# Training episode 353
# Time steps: 3549, Penalties: 1117, Reward: -13581
#
# Training episode 354
# Time steps: 1278, Penalties: 399, Reward: -4848
#
# Training episode 355
# Time steps: 464, Penalties: 124, Reward: -1559
#
# Training episode 356
# Time steps: 64, Penalties: 14, Reward: -169
#
# Training episode 357
# Time steps: 2114, Penalties: 693, Reward: -8330
#
# Training episode 358
# Time steps: 1748, Penalties: 566, Reward: -6821
#
# Training episode 359
# Time steps: 20, Penalties: 0, Reward: 1
#
# Training episode 360
# Time steps: 2281, Penalties: 770, Reward: -9190
#
# Training episode 361
# Time steps: 136, Penalties: 43, Reward: -502
#
# Training episode 362
# Time steps: 176, Penalties: 63, Reward: -722
#
# Training episode 363
# Time steps: 682, Penalties: 232, Reward: -2749
#
# Training episode 364
# Time steps: 144, Penalties: 46, Reward: -537
#
# Training episode 365
# Time steps: 558, Penalties: 197, Reward: -2310
#
# Training episode 366
# Time steps: 1267, Penalties: 402, Reward: -4864
#
# Training episode 367
# Time steps: 969, Penalties: 304, Reward: -3684
#
# Training episode 368
# Time steps: 5095, Penalties: 1679, Reward: -20185
#
# Training episode 369
# Time steps: 1879, Penalties: 626, Reward: -7492
#
# Training episode 370
# Time steps: 2265, Penalties: 707, Reward: -8607
#
# Training episode 371
# Time steps: 1376, Penalties: 427, Reward: -5198
#
# Training episode 372
# Time steps: 3253, Penalties: 1094, Reward: -13078
#
# Training episode 373
# Time steps: 513, Penalties: 179, Reward: -2103
#
# Training episode 374
# Time steps: 56, Penalties: 14, Reward: -161
#
# Training episode 375
# Time steps: 1616, Penalties: 548, Reward: -6527
#
# Training episode 376
# Time steps: 67, Penalties: 20, Reward: -226
#
# Training episode 377
# Time steps: 1089, Penalties: 353, Reward: -4245
#
# Training episode 378
# Time steps: 164, Penalties: 53, Reward: -620
#
# Training episode 379
# Time steps: 843, Penalties: 272, Reward: -3270
#
# Training episode 380
# Time steps: 758, Penalties: 237, Reward: -2870
#
# Training episode 381
# Time steps: 328, Penalties: 101, Reward: -1216
#
# Training episode 382
# Time steps: 400, Penalties: 116, Reward: -1423
#
# Training episode 383
# Time steps: 43, Penalties: 10, Reward: -112
#
# Training episode 384
# Time steps: 486, Penalties: 157, Reward: -1878
# Training episode 385
# Time steps: 1903, Penalties: 644, Reward: -7678
#
# Training episode 386
# Time steps: 94, Penalties: 33, Reward: -370
#
# Training episode 387
# Time steps: 244, Penalties: 84, Reward: -979
#
# Training episode 388
# Time steps: 1606, Penalties: 536, Reward: -6409
#
# Training episode 389
# Time steps: 42, Penalties: 14, Reward: -147
#
# Training episode 390
# Time steps: 471, Penalties: 150, Reward: -1800
#
# Training episode 391
# Time steps: 546, Penalties: 192, Reward: -2253
#
# Training episode 392
# Time steps: 868, Penalties: 270, Reward: -3277
#
# Training episode 393
# Time steps: 1778, Penalties: 593, Reward: -7094
#
# Training episode 394
# Time steps: 3052, Penalties: 1005, Reward: -12076
#
# Training episode 395
# Time steps: 215, Penalties: 71, Reward: -833
#
# Training episode 396
# Time steps: 101, Penalties: 35, Reward: -395
#
# Training episode 397
# Time steps: 1608, Penalties: 517, Reward: -6240
#
# Training episode 398
# Time steps: 174, Penalties: 56, Reward: -657
#
# Training episode 399
# Time steps: 1545, Penalties: 545, Reward: -6429
#
# Training episode 400
# Time steps: 107, Penalties: 27, Reward: -329
#
# Training episode 401
# Time steps: 397, Penalties: 111, Reward: -1375
#
# Training episode 402
# Time steps: 299, Penalties: 97, Reward: -1151
#
# Training episode 403
# Time steps: 141, Penalties: 58, Reward: -642
#
# Training episode 404
# Time steps: 1517, Penalties: 508, Reward: -6068
#
# Training episode 405
# Time steps: 269, Penalties: 79, Reward: -959
#
# Training episode 406
# Time steps: 352, Penalties: 113, Reward: -1348
#
# Training episode 407
# Time steps: 35, Penalties: 9, Reward: -95
#
# Training episode 408
# Time steps: 561, Penalties: 184, Reward: -2196
#
# Training episode 409
# Time steps: 1678, Penalties: 494, Reward: -6103
#
# Training episode 410
# Time steps: 70, Penalties: 21, Reward: -238
#
# Training episode 411
# Time steps: 54, Penalties: 20, Reward: -213
#
# Training episode 412
# Time steps: 1516, Penalties: 491, Reward: -5914
#
# Training episode 413
# Time steps: 191, Penalties: 73, Reward: -827
#
# Training episode 414
# Time steps: 2496, Penalties: 821, Reward: -9864
#
# Training episode 415
# Time steps: 1757, Penalties: 592, Reward: -7064
#
# Training episode 416
# Time steps: 1396, Penalties: 453, Reward: -5452
#
# Training episode 417
# Time steps: 1899, Penalties: 625, Reward: -7503
#
# Training episode 418
# Time steps: 38, Penalties: 11, Reward: -116
#
# Training episode 419
# Time steps: 2931, Penalties: 925, Reward: -11235
#
# Training episode 420
# Time steps: 724, Penalties: 222, Reward: -2701
#
# Training episode 421
# Time steps: 356, Penalties: 109, Reward: -1316
#
# Training episode 422
# Time steps: 3306, Penalties: 1064, Reward: -12861
#
# Training episode 423
# Time steps: 687, Penalties: 241, Reward: -2835
#
# Training episode 424
# Time steps: 144, Penalties: 34, Reward: -429
#
# Training episode 425
# Time steps: 1031, Penalties: 340, Reward: -4070
#
# Training episode 426
# Time steps: 491, Penalties: 160, Reward: -1910
#
# Training episode 427
# Time steps: 2018, Penalties: 691, Reward: -8216
#
# Training episode 428
# Time steps: 1105, Penalties: 342, Reward: -4162
#
# Training episode 429
# Time steps: 1778, Penalties: 590, Reward: -7067
#
# Training episode 430
# Time steps: 177, Penalties: 50, Reward: -606
#
# Training episode 431
# Time steps: 1146, Penalties: 343, Reward: -4212
#
# Training episode 432
# Time steps: 1398, Penalties: 455, Reward: -5472
#
# Training episode 433
# Time steps: 761, Penalties: 267, Reward: -3143
#
# Training episode 434
# Time steps: 431, Penalties: 130, Reward: -1580
#
# Training episode 435
# Time steps: 409, Penalties: 122, Reward: -1486
#
# Training episode 436
# Time steps: 995, Penalties: 312, Reward: -3782
#
# Training episode 437
# Time steps: 650, Penalties: 195, Reward: -2384
#
# Training episode 438
# Time steps: 209, Penalties: 59, Reward: -719
#
# Training episode 439
# Time steps: 192, Penalties: 74, Reward: -837
#
# Training episode 440
# Time steps: 2245, Penalties: 709, Reward: -8605
#
# Training episode 441
# Time steps: 4544, Penalties: 1486, Reward: -17897
#
# Training episode 442
# Time steps: 2344, Penalties: 704, Reward: -8659
#
# Training episode 443
# Time steps: 1012, Penalties: 349, Reward: -4132
#
# Training episode 444
# Time steps: 857, Penalties: 247, Reward: -3059
#
# Training episode 445
# Time steps: 2000, Penalties: 648, Reward: -7811
#
# Training episode 446
# Time steps: 232, Penalties: 62, Reward: -769
#
# Training episode 447
# Time steps: 314, Penalties: 106, Reward: -1247
#
# Training episode 448
# Time steps: 1152, Penalties: 385, Reward: -4596
#
# Training episode 449
# Time steps: 466, Penalties: 151, Reward: -1804
#
# Training episode 450
# Time steps: 128, Penalties: 37, Reward: -440
#
# Training episode 451
# Time steps: 112, Penalties: 42, Reward: -469
#
# Training episode 452
# Time steps: 895, Penalties: 260, Reward: -3214
#
# Training episode 453
# Time steps: 564, Penalties: 184, Reward: -2199
#
# Training episode 454
# Time steps: 339, Penalties: 95, Reward: -1173
#
# Training episode 455
# Time steps: 271, Penalties: 92, Reward: -1078
#
# Training episode 456
# Time steps: 477, Penalties: 166, Reward: -1950
#
# Training episode 457
# Time steps: 709, Penalties: 237, Reward: -2821
#
# Training episode 458
# Time steps: 946, Penalties: 303, Reward: -3652
#
# Training episode 459
# Time steps: 1902, Penalties: 630, Reward: -7551
#
# Training episode 460
# Time steps: 133, Penalties: 36, Reward: -436
#
# Training episode 461
# Time steps: 939, Penalties: 323, Reward: -3825
#
# Training episode 462
# Time steps: 441, Penalties: 132, Reward: -1608
#
# Training episode 463
# Time steps: 284, Penalties: 94, Reward: -1109
#
# Training episode 464
# Time steps: 446, Penalties: 137, Reward: -1658
#
# Training episode 465
# Time steps: 1190, Penalties: 390, Reward: -4679
#
# Training episode 466
# Time steps: 824, Penalties: 252, Reward: -3071
#
# Training episode 467
# Time steps: 350, Penalties: 119, Reward: -1400
#
# Training episode 468
# Time steps: 511, Penalties: 176, Reward: -2074
#
# Training episode 469
# Time steps: 604, Penalties: 176, Reward: -2167
#
# Training episode 470
# Time steps: 1811, Penalties: 585, Reward: -7055
#
# Training episode 471
# Time steps: 505, Penalties: 133, Reward: -1681
#
# Training episode 472
# Time steps: 1019, Penalties: 298, Reward: -3680
#
# Training episode 473
# Time steps: 64, Penalties: 13, Reward: -160
#
# Training episode 474
# Time steps: 3455, Penalties: 1136, Reward: -13658
#
# Training episode 475
# Time steps: 1090, Penalties: 385, Reward: -4534
#
# Training episode 476
# Time steps: 590, Penalties: 202, Reward: -2387
#
# Training episode 477
# Time steps: 142, Penalties: 43, Reward: -508
#
# Training episode 478
# Time steps: 53, Penalties: 14, Reward: -158
#
# Training episode 479
# Time steps: 884, Penalties: 266, Reward: -3257
#
# Training episode 480
# Time steps: 1034, Penalties: 311, Reward: -3812
#
# Training episode 481
# Time steps: 524, Penalties: 154, Reward: -1889
#
# Training episode 482
# Time steps: 302, Penalties: 95, Reward: -1136
#
# Training episode 483
# Time steps: 1307, Penalties: 429, Reward: -5147
#
# Training episode 484
# Time steps: 1966, Penalties: 625, Reward: -7570
#
# Training episode 485
# Time steps: 1315, Penalties: 418, Reward: -5056
#
# Training episode 486
# Time steps: 15, Penalties: 2, Reward: -12
#
# Training episode 487
# Time steps: 742, Penalties: 243, Reward: -2908
#
# Training episode 488
# Time steps: 2404, Penalties: 781, Reward: -9412
#
# Training episode 489
# Time steps: 1699, Penalties: 575, Reward: -6853
#
# Training episode 490
# Time steps: 90, Penalties: 29, Reward: -330
#
# Training episode 491
# Time steps: 447, Penalties: 142, Reward: -1704
#
# Training episode 492
# Time steps: 678, Penalties: 217, Reward: -2610
#
# Training episode 493
# Time steps: 946, Penalties: 310, Reward: -3715
#
# Training episode 494
# Time steps: 1151, Penalties: 361, Reward: -4379
#
# Training episode 495
# Time steps: 640, Penalties: 231, Reward: -2698
#
# Training episode 496
# Time steps: 244, Penalties: 80, Reward: -943
#
# Training episode 497
# Time steps: 1993, Penalties: 658, Reward: -7894
#
# Training episode 498
# Time steps: 483, Penalties: 166, Reward: -1956
#
# Training episode 499
# Time steps: 80, Penalties: 24, Reward: -275
#
# Training episode 500
# Time steps: 4812, Penalties: 1560, Reward: -18831
#
# Training episode 501
# Time steps: 798, Penalties: 262, Reward: -3135
#
# Training episode 502
# Time steps: 1753, Penalties: 556, Reward: -6736
#
# Training episode 503
# Time steps: 1312, Penalties: 467, Reward: -5494
#
# Training episode 504
# Time steps: 3119, Penalties: 1082, Reward: -12836
#
# Training episode 505
# Time steps: 144, Penalties: 33, Reward: -420
#
# Training episode 506
# Time steps: 2553, Penalties: 809, Reward: -9813
#
# Training episode 507
# Time steps: 552, Penalties: 198, Reward: -2313
#
# Training episode 508
# Time steps: 168, Penalties: 54, Reward: -633
#
# Training episode 509
# Time steps: 671, Penalties: 206, Reward: -2504
#
# Training episode 510
# Time steps: 44, Penalties: 11, Reward: -122
#
# Training episode 511
# Time steps: 33, Penalties: 7, Reward: -75
#
# Training episode 512
# Time steps: 33, Penalties: 7, Reward: -75
#
# Training episode 513
# Time steps: 390, Penalties: 124, Reward: -1485
#
# Training episode 514
# Time steps: 137, Penalties: 42, Reward: -494
#
# Training episode 515
# Time steps: 1846, Penalties: 564, Reward: -6901
#
# Training episode 516
# Time steps: 509, Penalties: 152, Reward: -1856
#
# Training episode 517
# Time steps: 274, Penalties: 77, Reward: -946
#
# Training episode 518
# Time steps: 148, Penalties: 49, Reward: -568
#
# Training episode 519
# Time steps: 199, Penalties: 67, Reward: -781
#
# Training episode 520
# Time steps: 698, Penalties: 238, Reward: -2819
#
# Training episode 521
# Time steps: 481, Penalties: 144, Reward: -1756
# Training episode 522
# Time steps: 2249, Penalties: 750, Reward: -8978
#
# Training episode 523
# Time steps: 926, Penalties: 296, Reward: -3569
#
# Training episode 524
# Time steps: 278, Penalties: 83, Reward: -1004
#
# Training episode 525
# Time steps: 476, Penalties: 149, Reward: -1796
#
# Training episode 526
# Time steps: 110, Penalties: 33, Reward: -386
#
# Training episode 527
# Time steps: 1912, Penalties: 623, Reward: -7498
#
# Training episode 528
# Time steps: 175, Penalties: 44, Reward: -550
#
# Training episode 529
# Time steps: 431, Penalties: 150, Reward: -1760
#
# Training episode 530
# Time steps: 1394, Penalties: 454, Reward: -5459
#
# Training episode 531
# Time steps: 1430, Penalties: 460, Reward: -5549
#
# Training episode 532
# Time steps: 1092, Penalties: 353, Reward: -4248
#
# Training episode 533
# Time steps: 549, Penalties: 162, Reward: -1986
#
# Training episode 534
# Time steps: 283, Penalties: 74, Reward: -928
#
# Training episode 535
# Time steps: 771, Penalties: 255, Reward: -3045
#
# Training episode 536
# Time steps: 115, Penalties: 28, Reward: -346
#
# Training episode 537
# Time steps: 2343, Penalties: 760, Reward: -9162
#
# Training episode 538
# Time steps: 24, Penalties: 2, Reward: -21
#
# Training episode 539
# Time steps: 454, Penalties: 144, Reward: -1729
#
# Training episode 540
# Time steps: 292, Penalties: 116, Reward: -1315
#
# Training episode 541
# Time steps: 318, Penalties: 88, Reward: -1089
#
# Training episode 542
# Time steps: 2910, Penalties: 968, Reward: -11601
#
# Training episode 543
# Time steps: 256, Penalties: 82, Reward: -973
#
# Training episode 544
# Time steps: 187, Penalties: 69, Reward: -787
#
# Training episode 545
# Time steps: 1643, Penalties: 503, Reward: -6149
#
# Training episode 546
# Time steps: 554, Penalties: 169, Reward: -2054
#
# Training episode 547
# Time steps: 620, Penalties: 219, Reward: -2570
#
# Training episode 548
# Time steps: 824, Penalties: 266, Reward: -3197
#
# Training episode 549
# Time steps: 448, Penalties: 139, Reward: -1678
#
# Training episode 550
# Time steps: 780, Penalties: 239, Reward: -2910
#
# Training episode 551
# Time steps: 651, Penalties: 221, Reward: -2619
#
# Training episode 552
# Time steps: 738, Penalties: 218, Reward: -2679
#
# Training episode 553
# Time steps: 266, Penalties: 86, Reward: -1019
#
# Training episode 554
# Time steps: 2427, Penalties: 814, Reward: -9732
#
# Training episode 555
# Time steps: 2658, Penalties: 874, Reward: -10503
#
# Training episode 556
# Time steps: 4757, Penalties: 1561, Reward: -18785
#
# Training episode 557
# Time steps: 138, Penalties: 34, Reward: -423
#
# Training episode 558
# Time steps: 2201, Penalties: 703, Reward: -8507
#
# Training episode 559
# Time steps: 1137, Penalties: 381, Reward: -4545
#
# Training episode 560
# Time steps: 136, Penalties: 39, Reward: -466
#
# Training episode 561
# Time steps: 470, Penalties: 148, Reward: -1781
#
# Training episode 562
# Time steps: 239, Penalties: 79, Reward: -929
#
# Training episode 563
# Time steps: 1860, Penalties: 621, Reward: -7428
#
# Training episode 564
# Time steps: 200, Penalties: 59, Reward: -710
#
# Training episode 565
# Time steps: 163, Penalties: 51, Reward: -601
#
# Training episode 566
# Time steps: 1616, Penalties: 541, Reward: -6464
#
# Training episode 567
# Time steps: 2355, Penalties: 772, Reward: -9282
#
# Training episode 568
# Time steps: 170, Penalties: 50, Reward: -599
#
# Training episode 569
# Time steps: 1676, Penalties: 523, Reward: -6362
#
# Training episode 570
# Time steps: 566, Penalties: 177, Reward: -2138
#
# Training episode 571
# Time steps: 164, Penalties: 43, Reward: -530
#
# Training episode 572
# Time steps: 362, Penalties: 126, Reward: -1475
#
# Training episode 573
# Time steps: 366, Penalties: 115, Reward: -1380
#
# Training episode 574
# Time steps: 512, Penalties: 153, Reward: -1868
#
# Training episode 575
# Time steps: 1598, Penalties: 512, Reward: -6185
#
# Training episode 576
# Time steps: 903, Penalties: 266, Reward: -3276
#
# Training episode 577
# Time steps: 774, Penalties: 262, Reward: -3111
#
# Training episode 578
# Time steps: 1194, Penalties: 406, Reward: -4827
#
# Training episode 579
# Time steps: 54, Penalties: 9, Reward: -114
#
# Training episode 580
# Time steps: 281, Penalties: 92, Reward: -1088
#
# Training episode 581
# Time steps: 47, Penalties: 16, Reward: -170
#
# Training episode 582
# Time steps: 1749, Penalties: 578, Reward: -6930
#
# Training episode 583
# Time steps: 397, Penalties: 135, Reward: -1591
#
# Training episode 584
# Time steps: 126, Penalties: 25, Reward: -330
#
# Training episode 585
# Time steps: 205, Penalties: 69, Reward: -805
#
# Training episode 586
# Time steps: 328, Penalties: 111, Reward: -1306
#
# Training episode 587
# Time steps: 34, Penalties: 7, Reward: -76
#
# Training episode 588
# Time steps: 196, Penalties: 49, Reward: -616
#
# Training episode 589
# Time steps: 78, Penalties: 25, Reward: -282
#
# Training episode 590
# Time steps: 1558, Penalties: 524, Reward: -6253
#
# Training episode 591
# Time steps: 475, Penalties: 147, Reward: -1777
#
# Training episode 592
# Time steps: 55, Penalties: 15, Reward: -169
#
# Training episode 593
# Time steps: 160, Penalties: 54, Reward: -625
#
# Training episode 594
# Time steps: 1118, Penalties: 326, Reward: -4031
#
# Training episode 595
# Time steps: 1144, Penalties: 364, Reward: -4399
#
# Training episode 596
# Time steps: 756, Penalties: 249, Reward: -2976
#
# Training episode 597
# Time steps: 2992, Penalties: 926, Reward: -11305
#
# Training episode 598
# Time steps: 1021, Penalties: 323, Reward: -3907
#
# Training episode 599
# Time steps: 281, Penalties: 92, Reward: -1088
#
# Training episode 600
# Time steps: 66, Penalties: 18, Reward: -207
#
# Training episode 601
# Time steps: 812, Penalties: 252, Reward: -3059
#
# Training episode 602
# Time steps: 324, Penalties: 124, Reward: -1419
#
# Training episode 603
# Time steps: 1044, Penalties: 375, Reward: -4398
#
# Training episode 604
# Time steps: 1322, Penalties: 416, Reward: -5045
#
# Training episode 605
# Time steps: 75, Penalties: 20, Reward: -234
#
# Training episode 606
# Time steps: 305, Penalties: 93, Reward: -1121
#
# Training episode 607
# Time steps: 398, Penalties: 114, Reward: -1403
#
# Training episode 608
# Time steps: 48, Penalties: 14, Reward: -153
#
# Training episode 609
# Time steps: 121, Penalties: 43, Reward: -487
#
# Training episode 610
# Time steps: 1203, Penalties: 389, Reward: -4683
#
# Training episode 611
# Time steps: 280, Penalties: 84, Reward: -1015
#
# Training episode 612
# Time steps: 902, Penalties: 274, Reward: -3347
#
# Training episode 613
# Time steps: 1396, Penalties: 428, Reward: -5227
#
# Training episode 614
# Time steps: 51, Penalties: 18, Reward: -192
#
# Training episode 615
# Time steps: 461, Penalties: 131, Reward: -1619
#
# Training episode 616
# Time steps: 5021, Penalties: 1610, Reward: -19490
#
# Training episode 617
# Time steps: 166, Penalties: 58, Reward: -667
#
# Training episode 618
# Time steps: 203, Penalties: 56, Reward: -686
#
# Training episode 619
# Time steps: 2180, Penalties: 729, Reward: -8720
#
# Training episode 620
# Time steps: 1054, Penalties: 373, Reward: -4390
#
# Training episode 621
# Time steps: 730, Penalties: 238, Reward: -2851
#
# Training episode 622
# Time steps: 274, Penalties: 81, Reward: -982
#
# Training episode 623
# Time steps: 974, Penalties: 317, Reward: -3806
#
# Training episode 624
# Time steps: 547, Penalties: 175, Reward: -2101
#
# Training episode 625
# Time steps: 547, Penalties: 199, Reward: -2317
#
# Training episode 626
# Time steps: 1235, Penalties: 398, Reward: -4796
#
# Training episode 627
# Time steps: 588, Penalties: 195, Reward: -2322
#
# Training episode 628
# Time steps: 653, Penalties: 211, Reward: -2531
#
# Training episode 629
# Time steps: 696, Penalties: 217, Reward: -2628
#
# Training episode 630
# Time steps: 189, Penalties: 54, Reward: -654
#
# Training episode 631
# Time steps: 4327, Penalties: 1425, Reward: -17131
#
# Training episode 632
# Time steps: 593, Penalties: 196, Reward: -2336
#
# Training episode 633
# Time steps: 802, Penalties: 272, Reward: -3229
#
# Training episode 634
# Time steps: 1641, Penalties: 546, Reward: -6534
#
# Training episode 635
# Time steps: 248, Penalties: 72, Reward: -875
#
# Training episode 636
# Time steps: 66, Penalties: 21, Reward: -234
#
# Training episode 637
# Time steps: 246, Penalties: 94, Reward: -1071
#
# Training episode 638
# Time steps: 3047, Penalties: 1023, Reward: -12233
#
# Training episode 639
# Time steps: 671, Penalties: 218, Reward: -2612
#
# Training episode 640
# Time steps: 1485, Penalties: 520, Reward: -6144
#
# Training episode 641
# Time steps: 2171, Penalties: 700, Reward: -8450
#
# Training episode 642
# Time steps: 119, Penalties: 32, Reward: -386
# Training episode 643
# Time steps: 943, Penalties: 309, Reward: -3703
#
# Training episode 644
# Time steps: 39, Penalties: 11, Reward: -117
#
# Training episode 645
# Time steps: 168, Penalties: 61, Reward: -696
#
# Training episode 646
# Time steps: 738, Penalties: 246, Reward: -2931
#
# Training episode 647
# Time steps: 137, Penalties: 48, Reward: -548
#
# Training episode 648
# Time steps: 265, Penalties: 75, Reward: -919
#
# Training episode 649
# Time steps: 2066, Penalties: 656, Reward: -7949
#
# Training episode 650
# Time steps: 1529, Penalties: 493, Reward: -5945
#
# Training episode 651
# Time steps: 4482, Penalties: 1464, Reward: -17637
#
# Training episode 652
# Time steps: 722, Penalties: 256, Reward: -3005
#
# Training episode 653
# Time steps: 590, Penalties: 186, Reward: -2243
#
# Training episode 654
# Time steps: 1126, Penalties: 350, Reward: -4255
#
# Training episode 655
# Time steps: 492, Penalties: 159, Reward: -1902
#
# Training episode 656
# Time steps: 1053, Penalties: 334, Reward: -4038
#
# Training episode 657
# Time steps: 335, Penalties: 105, Reward: -1259
#
# Training episode 658
# Time steps: 1596, Penalties: 489, Reward: -5976
#
# Training episode 659
# Time steps: 2053, Penalties: 659, Reward: -7963
#
# Training episode 660
# Time steps: 73, Penalties: 21, Reward: -241
#
# Training episode 661
# Time steps: 49, Penalties: 14, Reward: -154
#
# Training episode 662
# Time steps: 1520, Penalties: 489, Reward: -5900
#
# Training episode 663
# Time steps: 1456, Penalties: 481, Reward: -5764
#
# Training episode 664
# Time steps: 1267, Penalties: 414, Reward: -4972
#
# Training episode 665
# Time steps: 203, Penalties: 59, Reward: -713
#
# Training episode 666
# Time steps: 2308, Penalties: 758, Reward: -9109
#
# Training episode 667
# Time steps: 74, Penalties: 21, Reward: -242
#
# Training episode 668
# Time steps: 85, Penalties: 25, Reward: -289
#
# Training episode 669
# Time steps: 789, Penalties: 207, Reward: -2631
#
# Training episode 670
# Time steps: 133, Penalties: 41, Reward: -481
#
# Training episode 671
# Time steps: 223, Penalties: 71, Reward: -841
#
# Training episode 672
# Time steps: 901, Penalties: 281, Reward: -3409
#
# Training episode 673
# Time steps: 291, Penalties: 82, Reward: -1008
#
# Training episode 674
# Time steps: 91, Penalties: 30, Reward: -340
#
# Training episode 675
# Time steps: 2493, Penalties: 775, Reward: -9447
#
# Training episode 676
# Time steps: 427, Penalties: 142, Reward: -1684
#
# Training episode 677
# Time steps: 1298, Penalties: 406, Reward: -4931
#
# Training episode 678
# Time steps: 3251, Penalties: 1074, Reward: -12896
#
# Training episode 679
# Time steps: 80, Penalties: 25, Reward: -284
#
# Training episode 680
# Time steps: 350, Penalties: 105, Reward: -1274
#
# Training episode 681
# Time steps: 1304, Penalties: 431, Reward: -5162
#
# Training episode 682
# Time steps: 247, Penalties: 78, Reward: -928
#
# Training episode 683
# Time steps: 1513, Penalties: 497, Reward: -5965
#
# Training episode 684
# Time steps: 43, Penalties: 14, Reward: -148
#
# Training episode 685
# Time steps: 850, Penalties: 281, Reward: -3358
#
# Training episode 686
# Time steps: 162, Penalties: 47, Reward: -564
#
# Training episode 687
# Time steps: 368, Penalties: 122, Reward: -1445
#
# Training episode 688
# Time steps: 785, Penalties: 244, Reward: -2960
#
# Training episode 689
# Time steps: 489, Penalties: 134, Reward: -1674
#
# Training episode 690
# Time steps: 119, Penalties: 24, Reward: -314
#
# Training episode 691
# Time steps: 117, Penalties: 28, Reward: -348
#
# Training episode 692
# Time steps: 898, Penalties: 303, Reward: -3604
#
# Training episode 693
# Time steps: 1419, Penalties: 463, Reward: -5565
#
# Training episode 694
# Time steps: 28, Penalties: 5, Reward: -52
#
# Training episode 695
# Time steps: 1156, Penalties: 366, Reward: -4429
#
# Training episode 696
# Time steps: 1206, Penalties: 398, Reward: -4767
#
# Training episode 697
# Time steps: 990, Penalties: 299, Reward: -3660
#
# Training episode 698
# Time steps: 31, Penalties: 8, Reward: -82
#
# ...
# Time steps: 23, Penalties: 3, Reward: -29
#
# Training episode 9773
# Time steps: 91, Penalties: 33, Reward: -367
#
# Training episode 9774
# Time steps: 71, Penalties: 18, Reward: -212
#
# Training episode 9775
# Time steps: 309, Penalties: 96, Reward: -1152
#
# Training episode 9776
# Time steps: 877, Penalties: 318, Reward: -3718
#
# Training episode 9777
# Time steps: 337, Penalties: 103, Reward: -1243
#
# Training episode 9778
# Time steps: 1321, Penalties: 441, Reward: -5269
#
# Training episode 9779
# Time steps: 1395, Penalties: 445, Reward: -5379
#
# Training episode 9780
# Time steps: 850, Penalties: 276, Reward: -3313
#
# Training episode 9781
# Time steps: 1072, Penalties: 309, Reward: -3832
#
# Training episode 9782
# Time steps: 1623, Penalties: 509, Reward: -6183
#
# Training episode 9783
# Time steps: 1299, Penalties: 410, Reward: -4968
#
# Training episode 9784
# Time steps: 116, Penalties: 40, Reward: -455
#
# Training episode 9785
# Time steps: 1439, Penalties: 446, Reward: -5432
#
# Training episode 9786
# Time steps: 405, Penalties: 130, Reward: -1554
#
# Training episode 9787
# Time steps: 989, Penalties: 329, Reward: -3929
#
# Training episode 9788
# Time steps: 141, Penalties: 46, Reward: -534
#
# Training episode 9789
# Time steps: 434, Penalties: 138, Reward: -1655
#
# Training episode 9790
# Time steps: 58, Penalties: 13, Reward: -154
#
# Training episode 9791
# Time steps: 224, Penalties: 71, Reward: -842
#
# Training episode 9792
# Time steps: 1316, Penalties: 447, Reward: -5318
#
# Training episode 9793
# Time steps: 435, Penalties: 126, Reward: -1548
#
# Training episode 9794
# Time steps: 27, Penalties: 3, Reward: -33
#
# Training episode 9795
# Time steps: 923, Penalties: 290, Reward: -3512
#
# Training episode 9796
# Time steps: 1323, Penalties: 437, Reward: -5235
#
# Training episode 9797
# Time steps: 1113, Penalties: 358, Reward: -4314
#
# Training episode 9798
# Time steps: 439, Penalties: 162, Reward: -1876
#
# Training episode 9799
# Time steps: 394, Penalties: 129, Reward: -1534
#
# Training episode 9800
# Time steps: 128, Penalties: 34, Reward: -413
#
# Training episode 9801
# Time steps: 133, Penalties: 39, Reward: -463
#
# Training episode 9802
# Time steps: 1491, Penalties: 488, Reward: -5862
#
# Training episode 9803
# Time steps: 230, Penalties: 64, Reward: -785
#
# Training episode 9804
# Time steps: 940, Penalties: 320, Reward: -3799
#
# Training episode 9805
# Time steps: 74, Penalties: 21, Reward: -242
#
# Training episode 9806
# Time steps: 1460, Penalties: 485, Reward: -5804
#
# Training episode 9807
# Time steps: 199, Penalties: 75, Reward: -853
#
# Training episode 9808
# Time steps: 913, Penalties: 306, Reward: -3646
#
# Training episode 9809
# Time steps: 550, Penalties: 168, Reward: -2041
#
# Training episode 9810
# Time steps: 102, Penalties: 28, Reward: -333
#
# Training episode 9811
# Time steps: 2195, Penalties: 726, Reward: -8708
#
# Training episode 9812
# Time steps: 626, Penalties: 200, Reward: -2405
#
# Training episode 9813
# Time steps: 1225, Penalties: 417, Reward: -4957
#
# Training episode 9814
# Time steps: 241, Penalties: 85, Reward: -985
#
# Training episode 9815
# Time steps: 917, Penalties: 290, Reward: -3506
#
# Training episode 9816
# Time steps: 1243, Penalties: 410, Reward: -4912
#
# Training episode 9817
# Time steps: 3076, Penalties: 984, Reward: -11911
#
# Training episode 9818
# Time steps: 1264, Penalties: 430, Reward: -5113
#
# Training episode 9819
# Time steps: 1824, Penalties: 613, Reward: -7320
#
# Training episode 9820
# Time steps: 773, Penalties: 209, Reward: -2633
#
# Training episode 9821
# Time steps: 1586, Penalties: 527, Reward: -6308
#
# Training episode 9822
# Time steps: 2185, Penalties: 744, Reward: -8860
#
# Training episode 9823
# Time steps: 272, Penalties: 93, Reward: -1088
#
# Training episode 9824
# Time steps: 337, Penalties: 115, Reward: -1351
#
# Training episode 9825
# Time steps: 454, Penalties: 168, Reward: -1945
#
# Training episode 9826
# Time steps: 80, Penalties: 17, Reward: -212
#
# Training episode 9827
# Time steps: 631, Penalties: 197, Reward: -2383
#
# Training episode 9828
# Time steps: 1421, Penalties: 472, Reward: -5648
#
# Training episode 9829
# Time steps: 2127, Penalties: 772, Reward: -9054
#
# Training episode 9830
# Time steps: 349, Penalties: 120, Reward: -1408
#
# Training episode 9831
# Time steps: 106, Penalties: 23, Reward: -292
#
# Training episode 9832
# Time steps: 765, Penalties: 265, Reward: -3129
#
# Training episode 9833
# Time steps: 180, Penalties: 63, Reward: -726
#
# Training episode 9834
# Time steps: 136, Penalties: 46, Reward: -529
#
# Training episode 9835
# Time steps: 461, Penalties: 154, Reward: -1826
# Training episode 9836
# Time steps: 2547, Penalties: 885, Reward: -10491
#
# Training episode 9837
# Time steps: 1025, Penalties: 334, Reward: -4010
#
# Training episode 9838
# Time steps: 1748, Penalties: 557, Reward: -6740
#
# Training episode 9839
# Time steps: 454, Penalties: 145, Reward: -1738
#
# Training episode 9840
# Time steps: 1848, Penalties: 562, Reward: -6885
#
# Training episode 9841
# Time steps: 366, Penalties: 113, Reward: -1362
#
# Training episode 9842
# Time steps: 481, Penalties: 153, Reward: -1837
#
# Training episode 9843
# Time steps: 272, Penalties: 88, Reward: -1043
#
# Training episode 9844
# Time steps: 2063, Penalties: 645, Reward: -7847
#
# Training episode 9845
# Time steps: 997, Penalties: 310, Reward: -3766
#
# Training episode 9846
# Time steps: 1625, Penalties: 515, Reward: -6239
#
# Training episode 9847
# Time steps: 763, Penalties: 242, Reward: -2920
#
# Training episode 9848
# Time steps: 170, Penalties: 47, Reward: -572
#
# Training episode 9849
# Time steps: 1229, Penalties: 417, Reward: -4961
#
# Training episode 9850
# Time steps: 5414, Penalties: 1778, Reward: -21395
#
# Training episode 9851
# Time steps: 194, Penalties: 55, Reward: -668
#
# Training episode 9852
# Time steps: 2769, Penalties: 951, Reward: -11307
#
# Training episode 9853
# Time steps: 1700, Penalties: 565, Reward: -6764
#
# Training episode 9854
# Time steps: 254, Penalties: 82, Reward: -971
#
# Training episode 9855
# Time steps: 341, Penalties: 108, Reward: -1292
#
# Training episode 9856
# Time steps: 398, Penalties: 134, Reward: -1583
#
# Training episode 9857
# Time steps: 3406, Penalties: 1157, Reward: -13798
#
# Training episode 9858
# Time steps: 157, Penalties: 50, Reward: -586
#
# Training episode 9859
# Time steps: 811, Penalties: 273, Reward: -3247
#
# Training episode 9860
# Time steps: 1036, Penalties: 312, Reward: -3823
#
# Training episode 9861
# Time steps: 127, Penalties: 43, Reward: -493
#
# Training episode 9862
# Time steps: 484, Penalties: 179, Reward: -2074
#
# Training episode 9863
# Time steps: 1243, Penalties: 401, Reward: -4831
#
# Training episode 9864
# Time steps: 782, Penalties: 268, Reward: -3173
#
# Training episode 9865
# Time steps: 400, Penalties: 108, Reward: -1351
#
# Training episode 9866
# Time steps: 599, Penalties: 209, Reward: -2459
#
# Training episode 9867
# Time steps: 87, Penalties: 30, Reward: -336
#
# Training episode 9868
# Time steps: 712, Penalties: 225, Reward: -2716
#
# Training episode 9869
# Time steps: 48, Penalties: 6, Reward: -81
#
# Training episode 9870
# Time steps: 513, Penalties: 165, Reward: -1977
#
# Training episode 9871
# Time steps: 499, Penalties: 162, Reward: -1936
#
# Training episode 9872
# Time steps: 233, Penalties: 77, Reward: -905
#
# Training episode 9873
# Time steps: 56, Penalties: 14, Reward: -161
#
# Training episode 9874
# Time steps: 260, Penalties: 94, Reward: -1085
#
# Training episode 9875
# Time steps: 153, Penalties: 58, Reward: -654
#
# Training episode 9876
# Time steps: 2401, Penalties: 794, Reward: -9526
#
# Training episode 9877
# Time steps: 952, Penalties: 318, Reward: -3793
#
# Training episode 9878
# Time steps: 109, Penalties: 30, Reward: -358
#
# Training episode 9879
# Time steps: 687, Penalties: 225, Reward: -2691
#
# Training episode 9880
# Time steps: 227, Penalties: 71, Reward: -845
#
# Training episode 9881
# Time steps: 18, Penalties: 5, Reward: -42
#
# Training episode 9882
# Time steps: 1899, Penalties: 654, Reward: -7764
#
# Training episode 9883
# Time steps: 384, Penalties: 131, Reward: -1542
#
# Training episode 9884
# Time steps: 5654, Penalties: 1874, Reward: -22499
#
# Training episode 9885
# Time steps: 227, Penalties: 75, Reward: -881
#
# Training episode 9886
# Time steps: 281, Penalties: 99, Reward: -1151
#
# Training episode 9887
# Time steps: 201, Penalties: 71, Reward: -819
#
# Training episode 9888
# Time steps: 1621, Penalties: 525, Reward: -6325
#
# Training episode 9889
# Time steps: 405, Penalties: 126, Reward: -1518
#
# Training episode 9890
# Time steps: 59, Penalties: 17, Reward: -191
#
# Training episode 9891
# Time steps: 1288, Penalties: 425, Reward: -5092
#
# Training episode 9892
# Time steps: 60, Penalties: 15, Reward: -174
#
# Training episode 9893
# Time steps: 586, Penalties: 198, Reward: -2347
#
# Training episode 9894
# Time steps: 1015, Penalties: 344, Reward: -4090
#
# Training episode 9895
# Time steps: 585, Penalties: 194, Reward: -2310
#
# Training episode 9896
# Time steps: 1631, Penalties: 524, Reward: -6326
#
# Training episode 9897
# Time steps: 968, Penalties: 324, Reward: -3863
#
# Training episode 9898
# Time steps: 246, Penalties: 75, Reward: -900
#
# Training episode 9899
# Time steps: 226, Penalties: 72, Reward: -853
#
# Training episode 9900
# Time steps: 2794, Penalties: 903, Reward: -10900
#
# Training episode 9901
# Time steps: 187, Penalties: 69, Reward: -787
#
# Training episode 9902
# Time steps: 837, Penalties: 280, Reward: -3336
#
# Training episode 9903
# Time steps: 87, Penalties: 20, Reward: -246
#
# Training episode 9904
# Time steps: 912, Penalties: 286, Reward: -3465
#
# Training episode 9905
# Time steps: 503, Penalties: 154, Reward: -1868
#
# Training episode 9906
# Time steps: 615, Penalties: 176, Reward: -2178
#
# Training episode 9907
# Time steps: 1165, Penalties: 382, Reward: -4582
#
# Training episode 9908
# Time steps: 494, Penalties: 153, Reward: -1850
#
# Training episode 9909
# Time steps: 999, Penalties: 323, Reward: -3885
#
# Training episode 9910
# Time steps: 360, Penalties: 117, Reward: -1392
#
# Training episode 9911
# Time steps: 227, Penalties: 83, Reward: -953
#
# Training episode 9912
# Time steps: 413, Penalties: 133, Reward: -1589
#
# Training episode 9913
# Time steps: 490, Penalties: 171, Reward: -2008
#
# Training episode 9914
# Time steps: 514, Penalties: 170, Reward: -2023
#
# Training episode 9915
# Time steps: 819, Penalties: 277, Reward: -3291
#
# Training episode 9916
# Time steps: 1088, Penalties: 368, Reward: -4379
#
# Training episode 9917
# Time steps: 521, Penalties: 174, Reward: -2066
#
# Training episode 9918
# Time steps: 942, Penalties: 304, Reward: -3657
#
# Training episode 9919
# Time steps: 925, Penalties: 293, Reward: -3541
#
# Training episode 9920
# Time steps: 960, Penalties: 305, Reward: -3684
#
# Training episode 9921
# Time steps: 1365, Penalties: 445, Reward: -5349
#
# Training episode 9922
# Time steps: 1675, Penalties: 552, Reward: -6622
#
# Training episode 9923
# Time steps: 35, Penalties: 11, Reward: -113
#
# Training episode 9924
# Time steps: 1014, Penalties: 318, Reward: -3855
#
# Training episode 9925
# Time steps: 17, Penalties: 3, Reward: -23
#
# Training episode 9926
# Time steps: 230, Penalties: 69, Reward: -830
#
# Training episode 9927
# Time steps: 127, Penalties: 35, Reward: -421
#
# Training episode 9928
# Time steps: 290, Penalties: 84, Reward: -1025
#
# Training episode 9929
# Time steps: 78, Penalties: 26, Reward: -291
#
# Training episode 9930
# Time steps: 575, Penalties: 188, Reward: -2246
#
# Training episode 9931
# Time steps: 217, Penalties: 72, Reward: -844
#
# Training episode 9932
# Time steps: 1136, Penalties: 364, Reward: -4391
#
# Training episode 9933
# Time steps: 1048, Penalties: 347, Reward: -4150
#
# Training episode 9934
# Time steps: 621, Penalties: 192, Reward: -2328
#
# Training episode 9935
# Time steps: 251, Penalties: 82, Reward: -968
#
# Training episode 9936
# Time steps: 502, Penalties: 163, Reward: -1948
#
# Training episode 9937
# Time steps: 4039, Penalties: 1298, Reward: -15700
#
# Training episode 9938
# Time steps: 552, Penalties: 178, Reward: -2133
#
# Training episode 9939
# Time steps: 463, Penalties: 140, Reward: -1702
#
# Training episode 9940
# Time steps: 872, Penalties: 275, Reward: -3326
#
# Training episode 9941
# Time steps: 311, Penalties: 113, Reward: -1307
#
# Training episode 9942
# Time steps: 288, Penalties: 90, Reward: -1077
#
# Training episode 9943
# Time steps: 315, Penalties: 107, Reward: -1257
#
# Training episode 9944
# Time steps: 290, Penalties: 106, Reward: -1223
#
# Training episode 9945
# Time steps: 690, Penalties: 245, Reward: -2874
#
# Training episode 9946
# Time steps: 2540, Penalties: 825, Reward: -9944
#
# Training episode 9947
# Time steps: 430, Penalties: 136, Reward: -1633
#
# Training episode 9948
# Time steps: 779, Penalties: 250, Reward: -3008
#
# Training episode 9949
# Time steps: 3745, Penalties: 1227, Reward: -14767
#
# Training episode 9950
# Time steps: 2731, Penalties: 901, Reward: -10819
#
# Training episode 9951
# Time steps: 464, Penalties: 136, Reward: -1667
#
# Training episode 9952
# Time steps: 605, Penalties: 205, Reward: -2429
#
# Training episode 9953
# Time steps: 4250, Penalties: 1391, Reward: -16748
#
# Training episode 9954
# Time steps: 689, Penalties: 220, Reward: -2648
#
# Training episode 9955
# Time steps: 1181, Penalties: 385, Reward: -4625
# Training episode 9956
# Time steps: 3145, Penalties: 1080, Reward: -12844
#
# Training episode 9957
# Time steps: 560, Penalties: 189, Reward: -2240
#
# Training episode 9958
# Time steps: 732, Penalties: 246, Reward: -2925
#
# Training episode 9959
# Time steps: 2193, Penalties: 710, Reward: -8562
#
# Training episode 9960
# Time steps: 419, Penalties: 138, Reward: -1640
#
# Training episode 9961
# Time steps: 1292, Penalties: 375, Reward: -4646
#
# Training episode 9962
# Time steps: 642, Penalties: 200, Reward: -2421
#
# Training episode 9963
# Time steps: 1227, Penalties: 418, Reward: -4968
#
# Training episode 9964
# Time steps: 421, Penalties: 129, Reward: -1561
#
# Training episode 9965
# Time steps: 1785, Penalties: 592, Reward: -7092
#
# Training episode 9966
# Time steps: 1610, Penalties: 515, Reward: -6224
#
# Training episode 9967
# Time steps: 4080, Penalties: 1341, Reward: -16128
#
# Training episode 9968
# Time steps: 658, Penalties: 224, Reward: -2653
#
# Training episode 9969
# Time steps: 447, Penalties: 149, Reward: -1767
#
# Training episode 9970
# Time steps: 2897, Penalties: 963, Reward: -11543
#
# Training episode 9971
# Time steps: 871, Penalties: 287, Reward: -3433
#
# Training episode 9972
# Time steps: 683, Penalties: 199, Reward: -2453
#
# Training episode 9973
# Time steps: 679, Penalties: 237, Reward: -2791
#
# Training episode 9974
# Time steps: 616, Penalties: 193, Reward: -2332
#
# Training episode 9975
# Time steps: 1184, Penalties: 388, Reward: -4655
#
# Training episode 9976
# Time steps: 1701, Penalties: 567, Reward: -6783
#
# Training episode 9977
# Time steps: 171, Penalties: 55, Reward: -645
#
# Training episode 9978
# Time steps: 395, Penalties: 116, Reward: -1418
#
# Training episode 9979
# Time steps: 1525, Penalties: 497, Reward: -5977
#
# Training episode 9980
# Time steps: 146, Penalties: 43, Reward: -512
#
# Training episode 9981
# Time steps: 924, Penalties: 300, Reward: -3603
#
# Training episode 9982
# Time steps: 1440, Penalties: 475, Reward: -5694
#
# Training episode 9983
# Time steps: 388, Penalties: 117, Reward: -1420
#
# Training episode 9984
# Time steps: 574, Penalties: 196, Reward: -2317
#
# Training episode 9985
# Time steps: 689, Penalties: 246, Reward: -2882
#
# Training episode 9986
# Time steps: 920, Penalties: 281, Reward: -3428
#
# Training episode 9987
# Time steps: 965, Penalties: 340, Reward: -4004
#
# Training episode 9988
# Time steps: 2027, Penalties: 686, Reward: -8180
#
# Training episode 9989
# Time steps: 980, Penalties: 348, Reward: -4091
#
# Training episode 9990
# Time steps: 351, Penalties: 131, Reward: -1509
#
# Training episode 9991
# Time steps: 205, Penalties: 69, Reward: -805
#
# Training episode 9992
# Time steps: 216, Penalties: 81, Reward: -924
#
# Training episode 9993
# Time steps: 1252, Penalties: 430, Reward: -5101
#
# Training episode 9994
# Time steps: 513, Penalties: 175, Reward: -2067
#
# Training episode 9995
# Time steps: 496, Penalties: 155, Reward: -1870
#
# Training episode 9996
# Time steps: 1923, Penalties: 613, Reward: -7419
#
# Training episode 9997
# Time steps: 230, Penalties: 73, Reward: -866
#
# Training episode 9998
# Time steps: 1466, Penalties: 475, Reward: -5720
#
# Training episode 9999
# Time steps: 1470, Penalties: 515, Reward: -6084
#
# Training episode 10000
# Time steps: 1182, Penalties: 386, Reward: -4635
# Training finished.

# %% [markdown]
# ## Evaluation

# %%
NUM_EPISODES = 100


def evaluate_agent(q_table, env, num_trials):
    total_epochs, total_penalties = 0, 0

    print("Running episodes...")
    for _ in range(num_trials):
        state = env.reset()
        epochs, num_penalties, reward = 0, 0, 0

        while reward != 20:
            next_action = select_optimal_action(q_table,
                                                state,
                                                env.action_space)
            state, reward, _, _ = env.step(next_action)

            if reward == -10:
                num_penalties += 1

            epochs += 1

        total_penalties += num_penalties
        total_epochs += epochs

    average_time = total_epochs / float(num_trials)
    average_penalties = total_penalties / float(num_trials)
    print("Evaluation results after {} trials".format(num_trials))
    print("Average time steps taken: {}".format(average_time))
    print("Average number of penalties incurred: {}".format(average_penalties))


env = gym.make("Taxi-v3")
with open("q_table.pickle", 'rb') as f:
    q_table = pickle.load(f)
evaluate_agent(q_table, env, NUM_EPISODES)
# Out:
# Running episodes...
# Evaluation results after 100 trials
# Average time steps taken: 807.75
# Average number of penalties incurred: 262.44
